# %%
# !pip install --upgrade openai

# %%
import os

# %%
from openai import OpenAI

try:
    client = OpenAI()  # reads OPENAI_API_KEY

    response = client.chat.completions.create(
        model="gpt-4.1-mini",  # fast + cheap for testing
        messages=[
            {"role": "user", "content": "Hello! Testing my OpenAI API key from Jupyter."}
        ],
        max_tokens=30
    )

    print("✅ API key is working!")
    print("Model reply:")
    print(response.choices[0].message.content)

except Exception as e:
    print("❌ API key test failed")
    print(type(e).__name__, ":", e)
# Out:
# ✅ API key is working!
# Model reply:
# Hello! Your OpenAI API key seems to be working if you're able to run code from Jupyter. If you'd like, I can help you with
