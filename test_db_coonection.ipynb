# %%
DB_HOST="192.168.1.149"
DB_PORT="3307"
DB_USER="CBSUSER"
DB_PASSWORD="Falcon@2022"
DB_NAME="neo"

# %%
# These are my database credentials
## lets write a code to connect to the database using these credentials
import mysql.connector
from mysql.connector import Error
def create_connection(host_name, user_name, user_password, db_name):
    connection = None
    try:
        connection = mysql.connector.connect(
            host=host_name,
            user=user_name,
            password=user_password,
            database=db_name
        )
        print("Connection to MySQL DB successful")
    except Error as e:
        print(f"The error '{e}' occurred")
    return connection
connection = create_connection(DB_HOST, DB_USER, DB_PASSWORD, DB_NAME)
# Out:
# The error '2003 (HY000): Can't connect to MySQL server on '192.168.1.149:3306' (10060)' occurred

# %%
import csv

tables = set()

with open("data/database/Table_information.csv", encoding="utf-8-sig") as f:
    reader = csv.DictReader(f)
    for row in reader:
        tables.add(row["Table_name"].strip())

for t in sorted(tables):
    print(repr(t))
# Out:
# 'alarm_master'
# 'api_master'
# 'article_proximity_score'
# 'article_registered'
# 'articles_registered'
# 'auto_calibration_logs'
# 'bin_configuration'
# 'bin_info_master'
# 'bin_loading_wave_order_master'
# 'bin_velocity_scores'
# 'bot_alarm_log'
# 'bot_charging_bit_log'
# 'bot_manual_alarm_log'
# 'bot_master'
# 'bot_master_log'
# 'category_master'
# 'category_matrix'
# 'chatbot_chat_history'
# 'chatbot_column_corrections'
# 'chatbot_feedback'
# 'chatbot_query_patterns'
# 'chatbot_sql_queries'
# 'config_master'
# 'controller_reservations_master'
# 'dashboard_access_master'
# 'dashboard_bot_master'
# 'dashboard_breadcrumb_master'
# 'dashboard_config'
# 'dashboard_grid_points_master'
# 'dashboard_log_bot_charging'
# 'dashboard_log_error_api'
# 'dashboard_log_location_block_master'
# 'dashboard_log_maintenance_task_master'
# 'dashboard_log_manual_task_master'
# 'dashboard_log_user_login_attempts'
# 'dashboard_log_wave_process'
# 'dashboard_manual_task_master'
# ...
